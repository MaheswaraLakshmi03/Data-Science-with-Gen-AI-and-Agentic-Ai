# %% [markdown]
# String

# %%
s='welcome'

# %%
s
# Out:
# 'welcome'

# %%
id(s)
# Out:
# 1693250303584

# %%
 len(s)
# Out:
# 7

# %%
s1="welcome to naresh it"
s2='''welcome 
         to
           nit technology'''

# %%
print(s)
print(s1)
print(s2)
# Out:
# welcome
# welcome to naresh it
# welcome
#          to
#            nit technology

# %%
s4='welcome'

# %%
print(s)
print(s4)
# Out:
# welcome
# welcome

# %%
print(id(s))
print(id(s4))
# Out:
# 1693250303584
# 1693250303584

# %%
s[0]  #forward indexing
# Out:
# 'w'

# %%
s[6]
# Out:
# 'e'

# %%
s[4]
# Out:
# 'o'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s[-1]   #backward indexing
# Out:
# 'e'

# %%
s[-6]
# Out:
# 'e'

# %%
s[-7]
# Out:
# 'w'

# %% [markdown]
# String slicing

# %%
s[:]
# Out:
# 'welcome'

# %%
s[1:6]  #forward slicing
# Out:
# 'elcom'

# %%
s[2:]
# Out:
# 'lcome'

# %%
s[:7]
# Out:
# 'welcome'

# %%
s[:5]
# Out:
# 'welco'

# %%
s[:1000]
# Out:
# 'welcome'

# %%
s[1000:]
# Out:
# ''

# %%
s[-1:]  #backward slicing
# Out:
# 'e'

# %%
s[-6:]
# Out:
# 'elcome'

# %%
del s    #deleting the string
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 del s    #deleting the string
# ----> 2 print(s)
#
# NameError: name 's' is not defined

# %%
str1='Hello'
str2='Mahi'
str3=str1+' '+str2
print(str3)
# Out:
# Hello Mahi
