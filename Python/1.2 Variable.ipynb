# %%
num=10
NUM    #variable is the case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 num=10
# ----> 2 NUM
#
# NameError: name 'NUM' is not defined

# %%
1num=10
1num    #variable cannot start with numbers
# Out:
#   Cell In[2], line 1
#     1num=10
#     ^
# SyntaxError: invalid decimal literal

# %%
age =25
age     #age is the variable and 25 is the integer value
# Out:
# 25

# %%
name = 'mahi'
name          #name is the variable and 'mahi' is the string value
# Out:
# 'mahi'

# %%
a=3
b=4
a+b
# Out:
# 7

# %%
a=3
b=4
result=a+b
print(result)
# Out:
# 7

# %%
score =50
print(score)
score=100
print(score)
# Out:
# 50
# 100

# %%
first_name="mahi"
last_name="malladi"
full_name=first_name+" "+last_name
print(full_name)  #concatenating the strings
# Out:
# mahi malladi

# %%
length=7
width=3
area=length*width
print(area)
# Out:
# 21
