# %%
num1=10
num2=20
num3=30
add=num1+num2+num3
print('The addition of',num1,',',num2,'and',num3,'is=',add)
# Out:
# The addition of 10 , 20 and 30 is= 60

# %%
num1=20
num2=30
add=num1+num2
print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is= 50

# %%
num1=20
num2=30
add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 20 and 30 is= 50

# %%
print('hello team')
print('good morning')
# Out:
# hello team
# good morning

# %%
print('hello team',end=' ')
print('good morning')
# Out:
# hello team good morning

# %%
print('hello team',end=' ## ')
print('good morning')
# Out:
# hello team ## good morning
