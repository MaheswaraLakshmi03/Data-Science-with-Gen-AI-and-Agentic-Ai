# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# WORK WITH NUMBER

# %%
5
# Out:
# 5

# %%
#addition
3+5
# Out:
# 8

# %%
#subtraction
10-5
# Out:
# 5

# %%
#multiplication
10*5
# Out:
# 50

# %%
#division
10/2
# Out:
# 5.0

# %%
#floor division
10//2
# Out:
# 5

# %%
#modulus
10%5
# Out:
# 0

# %%
#exponent
3**2
# Out:
# 9

# %%
10*3-2+1 #DMAS
# Out:
# 29

# %%
10*3-(2+1)  #BODMAS
# Out:
# 27

# %%
2+3
10-3 #it only stores the recent value
# Out:
# 7

# %%
2-3
10-3
10*3 #it only stores the recent value
# Out:
# 30

# %%
print(2+3)
print(10-3)
print(10*3)
print(10/3)
# Out:
# 5
# 7
# 30
# 3.3333333333333335
