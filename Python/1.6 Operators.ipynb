# %% [markdown]
# Arithmetic Operator

# %%
x1, y1 = 10, 5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1**y1
# Out:
# 100000

# %%
x1%y1
# Out:
# 0

# %% [markdown]
# Assignment Operator

# %%
x=2

# %%
x = x+2

# %%
 x
# Out:
# 4

# %%
x+=2
x
# Out:
# 6

# %%
x-=2
x
# Out:
# 4

# %%
x*=2
x
# Out:
# 8

# %%
x/=2
x
# Out:
# 4.0

# %%
x//=2
x
# Out:
# 2.0

# %% [markdown]
# Relational Operators: we are using this operator for comaparing

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b=5

# %%
a==b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
a=5
b=4

# %%
a<8 and b<5
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
a<8 or b<2
# Out:
# True

# %%
a>8 or b<2
# Out:
# False

# %%
x=False
x
# Out:
# False

# %%
not x
# Out:
# True

# %% [markdown]
# Unary Operator

# %%
n=7
n
# Out:
# 7

# %%
m=-(n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7
